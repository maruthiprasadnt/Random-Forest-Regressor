# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Apr  8 17:04:53 2018

@author: maruthi
"""

# Random Forest Regressor
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
# Importing Data set
dataset = pd.read_csv('C:/Users/marut/Desktop/Random_Forest_Regression/Random_Forest_Regression/Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values
Y = dataset.iloc[:, 2].values

# Fitting Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators = 10, random_state = 0)
reg.fit(X, Y)

# Predicting the new result
y_pred = reg.predict(6.5)

print(y_pred)

# The predicted salary is shown below for 10 decision tree
# Out:
# [167000.]

# %%
# Visualising the Random_Forest_Regressor results for higher resolution and smoother curve
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X, Y, color = 'red')
plt.plot(X_grid, reg.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Random Forest Regressor)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# graph showing the results for 10 estimators (Decision tress)

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators = 10, random_state = 0)
reg.fit(X, Y)
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators = 100, random_state = 0)
reg.fit(X, Y)
# Predicting the new result
y_pred = reg.predict(6.5)

print(y_pred)

# The predicted salary is shown below for 100 decision tree
# Out:
# [158300.]

# %%
# Visualising the Random_Forest_Regressor results for higher resolution and smoother curve
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X, Y, color = 'red')
plt.plot(X_grid, reg.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Random Forest Regressor)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# graph showing the results for 100 estimators (Decision tress)

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators = 10, random_state = 0)
reg.fit(X, Y)
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators = 300, random_state = 0)
reg.fit(X, Y)
# Predicting the new result
y_pred = reg.predict(6.5)

print(y_pred)

# The predicted salary is shown below for 300 decision tree
# Out:
# [160333.33333333]

# %%
# Visualising the Random_Forest_Regressor results for higher resolution and smoother curve
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X, Y, color = 'red')
plt.plot(X_grid, reg.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Random Forest Regressor)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# graph showing the results for 300 estimators (Decision tress)
